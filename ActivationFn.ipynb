# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.v7labs.com/blog/neural-networks-activation-functions

# %% [markdown]
# ![image.png](attachment:image.png)
